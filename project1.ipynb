# %% [markdown]
# CLASS 1

# %%
import pandas as pd
import numpy as np
import statistics as stats

# %%
ages = [19, 22, 21, 35, 28, 24, 31, 19, 27, 40];
print(len(ages));
print(sum(ages));

mean_age = round(stats.mean(ages), 1)
print("this is your mean :" + str(mean_age))
print("this is the maximum age :" + str(max(ages)))
print("this is the minimum age :" + str(min(ages)))

median_age = stats.median(ages)
print("this is your median :" + str(median_age))


i think it Is because there Is an outlier in the data set. The maximum age of 40 is significantly higher than the other ages, which affected the skewness. median are less effected by outliers, which is why it may be a better measure of central tendency in this case.
# Out:
# 10
# 266
# this is your mean :26.6
# this is the maximum age :40
# this is the minimum age :19
# this is your median :25.5

# %% [markdown]
# CLASS 3

# %%
# Loading our CSV file into a dataframe named 'df'
df = pd.read_csv("50_Startups.csv")

# Checking the dimensions (rows and columns) of our dataset
df.shape

# Counting how many missing (null) values are in each column
print("Missing values per column:")
print(df.isnull().sum())

# Counting how many completely duplicate rows exist in the dataset
print("\nTotal duplicate rows:")
print(df.duplicated().sum())


# Removing any duplicate rows from the dataset
df = df.drop_duplicates()

# Cleaning the 'State' column by removing extra spaces and making it lowercase
df['State'] = df['State'].str.strip().str.lower()

# Forcing 'Marketing Spend' to be numbers (errors turn into empty values)
df['Marketing Spend'] = pd.to_numeric(df['Marketing Spend'], errors='coerce')

# Printing a message to let us know the cleaning is done
print("\nCleaning completed successfully!")


# Drawing a simple random sample of exactly 20 rows
simple_sample = df.sample(n=20, random_state=7)

# Drawing a stratified sample taking 20% from each State group
stratified_sample = (
    df.groupby("State", group_keys=False)
    .apply(lambda g: g.sample(frac=0.20, random_state=7))
)



# Printing the average (mean) of the full population
print("\n Population Means :")
print("R&D Spend:", df["R&D Spend"].mean())
print("Marketing Spend:", df["Marketing Spend"].mean())

# Printing the average of the simple random sample
print("\n Simple Sample Means:")
print("R&D Spend:", simple_sample["R&D Spend"].mean())
print("Marketing Spend:", simple_sample["Marketing Spend"].mean())

# Printing  the average of the stratified sample
print("\n Stratified Sample Means:")
print("R&D Spend:", stratified_sample["R&D Spend"].mean())
print("Marketing Spend:", stratified_sample["Marketing Spend"].mean())
# Out:
# Missing values per column:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64
#
# Total duplicate rows:
# 0
#
# Cleaning completed successfully!
#
#  Population Means :
# R&D Spend: 73721.6156
# Marketing Spend: 211025.09780000002
#
#  Simple Sample Means:
# R&D Spend: 76076.3745
# Marketing Spend: 245223.075
#
#  Stratified Sample Means:
# R&D Spend: 44181.63888888888
# Marketing Spend: 146787.40555555554

# %% [markdown]
# Because it guarantees that every single state gets its fair share in the sample. It stops important groups from being accidentally left out, which makes your final answers much more accurate than just picking names completely at random.

# %% [markdown]
# CLASS 2

# %%
import pandas as pd

# %%
# Print the shape (rows, columns)
print(df.shape)
# Out:
# (50, 5)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     str
#  4   Profit           50 non-null     float64
# dtypes: float64(4), str(1)
# memory usage: 2.1 KB

# %%
print(df.isnull().sum())
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
# Pulling as a Pandas Series (1D)
series_col = df['Profit']
print("Series Type:", type(series_col), "Shape:", series_col.shape)
# Out:
# Series Type: <class 'pandas.Series'> Shape: (50,)

# %%
# Pulling as a single-column DataFrame (2D)
df_col = df[['Profit']]
print("DataFrame Type:", type(df_col), "Shape:", df_col.shape)
# Out:
# DataFrame Type: <class 'pandas.DataFrame'> Shape: (50, 1)

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
# Export to JSON
df.to_json("startups.json", orient="records", indent=4)
